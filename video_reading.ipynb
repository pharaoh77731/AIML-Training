# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
import skimage as ski

# %%
#Video capture using web cam
vid = cv2.VideoCapture(0)
type(vid)
# Out:
# cv2.VideoCapture

# %%
vid.isOpened()
# Out:
# True

# %%
p = vid.read()
type(p)
len(p)
# Out:
# 2

# %%
p
# Out:
# (True,
#  array([[[199, 198, 193],
#          [195, 198, 193],
#          [192, 200, 194],
#          ...,
#          [132, 133, 132],
#          [133, 135, 137],
#          [130, 132, 135]],
#
#         [[198, 196, 192],
#          [196, 197, 192],
#          [193, 197, 192],
#          ...,
#          [129, 132, 131],
#          [132, 134, 134],
#          [131, 133, 133]],
#
#         [[198, 196, 192],
#          [196, 195, 191],
#          [194, 195, 191],
#          ...,
#          [130, 134, 131],
#          [130, 135, 132],
#          [130, 135, 132]],
#
#         ...,
#
#         [[ 83, 104, 109],
#          [ 86, 106, 111],
#          [ 93, 112, 117],
#          ...,
#          [ 81,  89,  93],
#          [ 80,  88,  92],
#          [ 79,  87,  91]],
#
#         [[ 77, 103, 110],
#          [ 78, 104, 112],
#          [ 79, 105, 114],
#          ...,
#          [ 84,  90,  91],
#          [ 85,  90,  91],
#          [ 86,  90,  91]],
#
#         [[ 59,  88, 101],
# ...

# %%
plt.imshow(p[1])   #bgr format

# %%
plt.imshow(p[1][:,:,::-1])       
#[:,:,::-1] used to reverse array or list
#rgb format obtained
